# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
file_path = "../../data/Cuernavaca_Enero_comas.csv"
df1 = pd.read_csv(file_path, index_col=0, parse_dates=True)
df1.index
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 01:00:00',
#                '2012-01-01 02:00:00', '2012-01-01 03:00:00',
#                '2012-01-01 04:00:00', '2012-01-01 05:00:00',
#                '2012-01-01 06:00:00', '2012-01-01 07:00:00',
#                '2012-01-01 08:00:00', '2012-01-01 09:00:00',
#                ...
#                '2012-01-31 14:00:00', '2012-01-31 15:00:00',
#                '2012-01-31 16:00:00', '2012-01-31 17:00:00',
#                '2012-01-31 18:00:00', '2012-01-31 19:00:00',
#                '2012-01-31 20:00:00', '2012-01-31 21:00:00',
#                '2012-01-31 22:00:00', '2012-01-31 23:00:00'],
#               dtype='datetime64[ns]', name='tiempo', length=744, freq=None)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

f1 = parse("2012-01-01")
f2 = f1 + pd.Timedelta("1d")

ax.plot(df1.Ig,"r-", label="Ig")
ax.plot(df1.Ib,"k--", label="Ib")
ax.plot(df1.Id,"bo-", label="Id")

ax.set_xlim(f1, f2)
ax.grid()
ax.legend()
ax.set_xlabel("Tiempo [mm-dd HH]")
ax.set_ylabel("Radiación $[µW/m²]$")
ax.set_title("Radiación Solar en Cuernavaca")
# Out:
# Text(0.5, 1.0, 'Radiación Solar en Cuernavaca')
