# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import glob as glob

# %%
glob.glob("../../data/esolmet/*")
# Out:
# ['../../data/esolmet\\001.xls',
#  '../../data/esolmet\\002.xls',
#  '../../data/esolmet\\003.xls',
#  '../../data/esolmet\\004.xls',
#  '../../data/esolmet\\005.xls',
#  '../../data/esolmet\\006.xls',
#  '../../data/esolmet\\007.xls',
#  '../../data/esolmet\\008.xls',
#  '../../data/esolmet\\009.xls',
#  '../../data/esolmet\\010.xls',
#  '../../data/esolmet\\011.xls',
#  '../../data/esolmet\\012.xls',
#  '../../data/esolmet\\esolmet.xlsx']

# %%
file_path = "../../data/esolmet/001.xls"
e1 = pd.read_excel(file_path, index_col=0, parse_dates=True, skiprows=[0,1,3,4])
e1.head()
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:20:00    0.170     0.0     0.0  0.001        18.92    40.96
# 2018-01-01 00:30:00    0.371     0.0     0.0  0.001        18.52    42.46
# 2018-01-01 00:40:00    0.305     0.0     0.0  0.001        18.49    42.43
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# 2018-01-01 00:00:00        1.253      879.0692
# 2018-01-01 00:10:00        0.418      879.4363
# 2018-01-01 00:20:00        0.955      879.5181
# 2018-01-01 00:30:00        1.823      879.5826
# 2018-01-01 00:40:00        2.149      879.6826

# %%
e1.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:10:00',
#                '2018-01-01 00:20:00', '2018-01-01 00:30:00',
#                '2018-01-01 00:40:00', '2018-01-01 00:50:00',
#                '2018-01-01 01:00:00', '2018-01-01 01:10:00',
#                '2018-01-01 01:20:00', '2018-01-01 01:30:00',
#                ...
#                '2018-01-31 22:30:00', '2018-01-31 22:40:00',
#                '2018-01-31 22:50:00', '2018-01-31 23:00:00',
#                '2018-01-31 23:10:00', '2018-01-31 23:20:00',
#                '2018-01-31 23:30:00', '2018-01-31 23:40:00',
#                '2018-01-31 23:50:00', '2018-02-01 00:00:00'],
#               dtype='datetime64[ns]', name='Fecha', length=4465, freq=None)

# %%
file_path = "../../data/esolmet/002.xls"
e2 = pd.read_excel(file_path, index_col=0, parse_dates=True, skiprows=[0,1,3,4])
e2.head()
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-02-01 00:00:00    0.003     0.0     0.0  0.001        15.38    53.71
# 2018-02-01 00:10:00    0.313     0.0     0.0  0.001        15.71    50.03
# 2018-02-01 00:20:00    0.029     0.0     0.0  0.001        15.57    51.52
# 2018-02-01 00:30:00    0.013     0.0     0.0  0.001        15.23    52.00
# 2018-02-01 00:40:00    0.001     0.0     0.0  0.001        15.28    51.80
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# 2018-02-01 00:00:00        1.531      878.2341
# 2018-02-01 00:10:00        2.339      878.1605
# 2018-02-01 00:20:00        2.836      877.9796
# 2018-02-01 00:30:00        2.780      877.9725
# 2018-02-01 00:40:00        2.541      878.0463

# %%
e = pd.concat([e1, e2])
e
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:20:00    0.170     0.0     0.0  0.001        18.92    40.96
# 2018-01-01 00:30:00    0.371     0.0     0.0  0.001        18.52    42.46
# 2018-01-01 00:40:00    0.305     0.0     0.0  0.001        18.49    42.43
# ...                      ...     ...     ...    ...          ...      ...
# 2018-02-28 23:20:00    0.000     0.0     0.0  0.000        22.49    38.44
# 2018-02-28 23:30:00    0.000     0.0     0.0  0.000        22.75    39.60
# 2018-02-28 23:40:00    0.003     0.0     0.0  0.000        22.34    39.43
# 2018-02-28 23:50:00    0.117     0.0     0.0  0.000        22.52    39.90
# 2018-03-01 00:00:00    0.004     0.0     0.0  0.000        22.35    41.03
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# ...

# %%
e.UV.plot()
# Out:
# <Axes: xlabel='Fecha'>

# %%
pd.concat([e1,e2], axis=1)
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:20:00    0.170     0.0     0.0  0.001        18.92    40.96
# 2018-01-01 00:30:00    0.371     0.0     0.0  0.001        18.52    42.46
# 2018-01-01 00:40:00    0.305     0.0     0.0  0.001        18.49    42.43
# ...                      ...     ...     ...    ...          ...      ...
# 2018-02-28 23:20:00      NaN     NaN     NaN    NaN          NaN      NaN
# 2018-02-28 23:30:00      NaN     NaN     NaN    NaN          NaN      NaN
# 2018-02-28 23:40:00      NaN     NaN     NaN    NaN          NaN      NaN
# 2018-02-28 23:50:00      NaN     NaN     NaN    NaN          NaN      NaN
# 2018-03-01 00:00:00      NaN     NaN     NaN    NaN          NaN      NaN
#
# ...

# %%
archivos = glob.glob("../../data/esolmet/*")
pd.concat([pd.read_excel(archivo,index_col=0, parse_dates=True, skiprows=[0,1,3,4]) for archivo in archivos])
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:20:00    0.170     0.0     0.0  0.001        18.92    40.96
# 2018-01-01 00:30:00    0.371     0.0     0.0  0.001        18.52    42.46
# 2018-01-01 00:40:00    0.305     0.0     0.0  0.001        18.49    42.43
# ...                      ...     ...     ...    ...          ...      ...
# 2018-01-31 23:20:00    0.000     0.0     0.0  0.001        15.82    52.51
# 2018-01-31 23:30:00    0.000     0.0     0.0  0.001        15.42    53.71
# 2018-01-31 23:40:00    0.081     0.0     0.0  0.001        15.28    53.26
# 2018-01-31 23:50:00    0.075     0.0     0.0  0.001        15.32    52.38
# 2018-02-01 00:00:00    0.003     0.0     0.0  0.001        15.38    53.71
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# ...

# %%
archivos = glob.glob("../../data/esolmet/*")
def group_files (file_path):
    files = [pd.read_excel(archivo,index_col=0, parse_dates=True, skiprows=[0,1,3,4]) for archivo in archivos]
    return pd.concat(files)

df = group_files(archivos)
df.sort_index(inplace=True)
df
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:00:00    0.057     0.0     0.0  0.001        18.93    41.57
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:10:00    0.002     0.0     0.0  0.001        18.76    41.00
# 2018-01-01 00:20:00    0.170     0.0     0.0  0.001        18.92    40.96
# ...                      ...     ...     ...    ...          ...      ...
# 2018-12-31 23:20:00    0.000     0.0     0.0  0.000        18.71    59.67
# 2018-12-31 23:30:00    0.044     0.0     0.0  0.000        18.52    58.75
# 2018-12-31 23:40:00    0.170     0.0     0.0  0.000        18.36    60.62
# 2018-12-31 23:50:00    0.003     0.0     0.0  0.000        17.99    60.76
# 2019-01-01 00:00:00    0.028     0.0     0.0  0.000        17.85    59.02
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# ...
