# %%
import pandas as pd

# %%
file_path = '../data/Cuernavaca_1dia_comas.csv'
df = pd.read_csv(
    file_path,
    index_col=0,
    parse_dates=True
)

df.head()
# Out:
#                        To   Ws  Wd      P  Ig  Ib  Id
# tiempo
# 2012-01-01 00:00:00  19.3  0.0  26  87415   0   0   0
# 2012-01-01 01:00:00  18.6  0.0  26  87602   0   0   0
# 2012-01-01 02:00:00  17.9  0.0  30  87788   0   0   0
# 2012-01-01 03:00:00  17.3  0.0  30  87554   0   0   0
# 2012-01-01 04:00:00  16.6  0.0  27  87321   0   0   0

# %%
columnas = df.columns
columnas
# Out:
# Index(['To', 'Ws', 'Wd', 'P', 'Ig', 'Ib', 'Id'], dtype='object')

# %%
nombres = {
    'Wd': 'Wind direction',
    'Ws': 'Wind speed',
    'T': 'Temperature',
    'P': 'Pressure',
    'RH': 'Relative Humidity'
}

# %%
df.rename(columns=nombres, inplace=True)

# %%
df
# Out:
#                        To  Wind speed  Wind direction  Pressure   Ig   Ib  Id
# tiempo
# 2012-01-01 00:00:00  19.3         0.0              26     87415    0    0   0
# 2012-01-01 01:00:00  18.6         0.0              26     87602    0    0   0
# 2012-01-01 02:00:00  17.9         0.0              30     87788    0    0   0
# 2012-01-01 03:00:00  17.3         0.0              30     87554    0    0   0
# 2012-01-01 04:00:00  16.6         0.0              27     87321    0    0   0
# 2012-01-01 05:00:00  15.9         0.0              26     87087    0    0   0
# 2012-01-01 06:00:00  17.0         0.0              27     87096    0    0   0
# 2012-01-01 07:00:00  18.0         0.0              34     87140   20  151  11
# 2012-01-01 08:00:00  19.0         0.0              61     87185  164  522  37
# 2012-01-01 09:00:00  20.0         0.0              95     87229  369  812  58
# 2012-01-01 10:00:00  20.0         1.0             108     87229  568  931  68
# ...

# %%
columnas = df.columns
columnas
# Out:
# Index(['To', 'Wind speed', 'Wind direction', 'Pressure', 'Ig', 'Ib', 'Id'], dtype='object')

# %%
viento = [columna for columna in columnas if 'wind' in columna.lower()]

# %%
df[viento]
# Out:
#                      Wind speed  Wind direction
# tiempo
# 2012-01-01 00:00:00         0.0              26
# 2012-01-01 01:00:00         0.0              26
# 2012-01-01 02:00:00         0.0              30
# 2012-01-01 03:00:00         0.0              30
# 2012-01-01 04:00:00         0.0              27
# 2012-01-01 05:00:00         0.0              26
# 2012-01-01 06:00:00         0.0              27
# 2012-01-01 07:00:00         0.0              34
# 2012-01-01 08:00:00         0.0              61
# 2012-01-01 09:00:00         0.0              95
# 2012-01-01 10:00:00         1.0             108
# 2012-01-01 11:00:00         2.1             160
# 2012-01-01 12:00:00         1.8             135
# 2012-01-01 13:00:00         1.5             160
# 2012-01-01 14:00:00         1.3             164
# 2012-01-01 15:00:00         1.2             176
# 2012-01-01 16:00:00         1.0             140
# 2012-01-01 17:00:00         0.0             198
# ...
